# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("retail_sales_dataset.csv")

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.tail()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date']
# Out:
# 0     2023-11-24
# 1     2023-02-27
# 2     2023-01-13
# 3     2023-05-21
# 4     2023-05-06
#          ...
# 995   2023-05-16
# 996   2023-11-17
# 997   2023-10-29
# 998   2023-12-05
# 999   2023-04-12
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
df['Gender'] = df['Gender'].astype('category')
df['Gender']
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3        Male
# 4        Male
#         ...
# 995      Male
# 996      Male
# 997    Female
# 998    Female
# 999      Male
# Name: Gender, Length: 1000, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
df['Product Category'] = df['Product Category'].astype('category')
df['Product Category']
# Out:
# 0           Beauty
# 1         Clothing
# 2      Electronics
# 3         Clothing
# 4           Beauty
#           ...
# 995       Clothing
# 996         Beauty
# 997         Beauty
# 998    Electronics
# 999    Electronics
# Name: Product Category, Length: 1000, dtype: category
# Categories (3, object): ['Beauty', 'Clothing', 'Electronics']

# %%
df.dtypes
# Out:
# Transaction ID               int64
# Date                datetime64[ns]
# Customer ID                 object
# Gender                    category
# Age                          int64
# Product Category          category
# Quantity                     int64
# Price per Unit               int64
# Total Amount                 int64
# dtype: object

# %%
df.drop('Transaction ID', axis=1, inplace=True)

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.nunique()
# Out:
# Date                 345
# Customer ID         1000
# Gender                 2
# Age                   47
# Product Category       3
# Quantity               4
# Price per Unit         5
# Total Amount          18
# dtype: int64

# %%
df['Date'].describe()
# Out:
# count                             1000
# mean     2023-07-03 00:25:55.200000256
# min                2023-01-01 00:00:00
# 25%                2023-04-08 00:00:00
# 50%                2023-06-29 12:00:00
# 75%                2023-10-04 00:00:00
# max                2024-01-01 00:00:00
# Name: Date, dtype: object

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    510
# Male      490
# Name: count, dtype: int64

# %%
df['Product Category'].value_counts()
# Out:
# Product Category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64

# %%
df['Product Category'].value_counts().plot(kind='bar', color='orange')
# Out:
# <Axes: xlabel='Product Category'>

# %%
df['Age'].describe()
# Out:
# count    1000.00000
# mean       41.39200
# std        13.68143
# min        18.00000
# 25%        29.00000
# 50%        42.00000
# 75%        53.00000
# max        64.00000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].skew()
# Out:
# -0.04881245380328967

# %%
df['Quantity'].describe()
# Out:
# count    1000.000000
# mean        2.514000
# std         1.132734
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: Quantity, dtype: float64

# %%
df['Quantity'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Quantity'>

# %%
df['Price per Unit'].describe()
# Out:
# count    1000.000000
# mean      179.890000
# std       189.681356
# min        25.000000
# 25%        30.000000
# 50%        50.000000
# 75%       300.000000
# max       500.000000
# Name: Price per Unit, dtype: float64

# %%
sns.histplot(df, x='Price per Unit')
plt.show()

# %%
df['Total Amount'].describe()
# Out:
# count    1000.000000
# mean      456.000000
# std       559.997632
# min        25.000000
# 25%        60.000000
# 50%       135.000000
# 75%       900.000000
# max      2000.000000
# Name: Total Amount, dtype: float64

# %%
plt.figure(figsize=(6,3))
sns.histplot(df['Total Amount'])
plt.title('Total Amount Distribution')
plt.show()

# %%
sns.scatterplot(df, x='Age', y='Total Amount')
# Out:
# <Axes: xlabel='Age', ylabel='Total Amount'>

# %%
df['Age'].corr(df['Total Amount'])
# Out:
# -0.060568023883045656

# %%
sns.scatterplot(df, x='Price per Unit', y='Total Amount')
# Out:
# <Axes: xlabel='Price per Unit', ylabel='Total Amount'>

# %%
df['Price per Unit'].corr(df['Total Amount'])
# Out:
# 0.8519248403554038

# %%
sns.scatterplot(df, x='Quantity', y='Total Amount')
# Out:
# <Axes: xlabel='Quantity', ylabel='Total Amount'>

# %%
df['Quantity'].corr(df['Total Amount'])
# Out:
# 0.37370705412140603

# %%
pd.crosstab(df['Gender'], df['Product Category'])
# Out:
# Product Category  Beauty  Clothing  Electronics
# Gender
# Female               166       174          170
# Male                 141       177          172

# %%
pd.crosstab(df['Gender'], df['Quantity'])
# Out:
# Quantity    1    2    3    4
# Gender
# Female    125  120  127  138
# Male      128  123  114  125

# %%
pd.crosstab(df['Product Category'], df['Quantity'])
# Out:
# Quantity           1   2   3   4
# Product Category
# Beauty            74  75  85  73
# Clothing          88  80  86  97
# Electronics       91  88  70  93

# %%
pd.crosstab(df['Gender'], df['Price per Unit'])
# Out:
# Price per Unit  25   30   50   300  500
# Gender
# Female          115   92   98  106   99
# Male             95   91  113   91  100

# %%
sns.boxplot(df, x='Gender', y='Total Amount')
# Out:
# <Axes: xlabel='Gender', ylabel='Total Amount'>

# %%
sns.boxplot(df, x='Product Category', y='Total Amount')
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Amount'>

# %%
sns.boxplot(df, x='Price per Unit', y='Total Amount')
# Out:
# <Axes: xlabel='Price per Unit', ylabel='Total Amount'>

# %%
sns.boxplot(df, x='Quantity', y='Total Amount')
# Out:
# <Axes: xlabel='Quantity', ylabel='Total Amount'>

# %%
sns.boxplot(df, x='Product Category', y='Total Amount', hue='Gender')
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Amount'>

# %%
sns.boxplot(df, x='Price per Unit', y='Total Amount', hue='Gender')
# Out:
# <Axes: xlabel='Price per Unit', ylabel='Total Amount'>

# %%
sns.pairplot(data=df)
# Out:
# C:\Users\Kesha\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
mean = np.mean(df["Age"])
mean
# Out:
# 41.392

# %%
median = np.median(df["Age"])
median
# Out:
# 42.0

# %%
variance = np.var(df["Age"])
variance
# Out:
# 186.994336

# %%
std = np.std(df["Age"])
std
# Out:
# 13.674587233258633

# %%
max = np.max(df["Age"])
max
# Out:
# 64

# %%
min = np.min(df["Age"])
min
# Out:
# 18

# %%
percentile = np.percentile(df["Age"], 60)
percentile
# Out:
# 46.0

# %%
quartile = np.quantile(df["Age"], 0.75)
quartile
# Out:
# 53.0

# %%
mean = np.mean(df["Price per Unit"])
mean
# Out:
# 179.89

# %%
mean = np.mean(df["Total Amount"])
mean
# Out:
# 456.0

# %%
median = np.median(df["Price per Unit"])
median
# Out:
# 50.0

# %%
median = np.median(df["Total Amount"])
median
# Out:
# 135.0

# %%
variance = np.var(df["Price per Unit"])
variance
# Out:
# 35943.0379

# %%
variance = np.var(df["Total Amount"])
variance
# Out:
# 313283.75

# %%
std = np.std(df["Price per Unit"])
std
# Out:
# 189.58649187112462

# %%
std = np.std(df["Total Amount"])
std
# Out:
# 559.7175627046198

# %%
max = np.max(df["Price per Unit"])
max
# Out:
# 500

# %%
max = np.max(df["Total Amount"])
max
# Out:
# 2000

# %%
min = np.min(df["Price per Unit"])
min
# Out:
# 25

# %%
min = np.min(df["Total Amount"])
min
# Out:
# 25

# %%
percentile = np.percentile(df["Total Amount"], 60)
percentile
# Out:
# 200.0

# %%
percentile = np.percentile(df["Price per Unit"], 60)
percentile
# Out:
# 50.0

# %%
quartile = np.quantile(df["Price per Unit"], 0.75)
quartile
# Out:
# 300.0

# %%
quartile = np.quantile(df["Total Amount"], 0.75)
quartile
# Out:
# 900.0
